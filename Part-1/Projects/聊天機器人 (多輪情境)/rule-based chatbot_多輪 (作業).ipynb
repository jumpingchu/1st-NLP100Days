# %% [markdown]
# # 1. Linebot 設計
#
# ## 當 query 包含"身高"、"體重"、"年齡"、"收入"等隱私時，回覆以下貼圖

# %%
from IPython.display import Image 
Image(filename='play_dumb.PNG')

# %% [markdown]
# # 2. 以 Python 實現多輪對話
#
# ## 於多輪對話情境中加入"取得股價資訊的功能"，query 為公司簡稱時(ex.鴻海)，即輸出2020/12/1~12/10之股價資訊
